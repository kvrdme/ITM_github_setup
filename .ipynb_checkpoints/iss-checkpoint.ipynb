# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install cartopy

# %%
import matplotlib.pyplot as plt
import requests

# %%
url = 'http://api.open-notify.org/iss-now.json'

# %%
import requests
import time

data_points = []
num_data_points = 100
interval = 10  #seconds

#making API requests
for i in range(num_data_points):
    response = requests.get(url)
    data = response.json()
    timestamp = data['timestamp']
    latitude = float(data['iss_position']['latitude'])
    longitude = float(data['iss_position']['longitude'])
    data_points.append({'timestamp': timestamp, 'latitude': latitude, 'longitude': longitude})
    time.sleep(interval)

#printing the generated data points
for data_point in data_points:
    print(data_point)
# Out:
# {'timestamp': 1688631094, 'latitude': 50.6388, 'longitude': -98.4502}
# {'timestamp': 1688631105, 'latitude': 50.7728, 'longitude': -97.4413}
# {'timestamp': 1688631115, 'latitude': 50.8916, 'longitude': -96.475}
# {'timestamp': 1688631125, 'latitude': 51.0017, 'longitude': -95.5038}
# {'timestamp': 1688631135, 'latitude': 51.1077, 'longitude': -94.4788}
# {'timestamp': 1688631146, 'latitude': 51.1996, 'longitude': -93.4986}
# {'timestamp': 1688631156, 'latitude': 51.2826, 'longitude': -92.5143}
# {'timestamp': 1688631166, 'latitude': 51.36, 'longitude': -91.4772}
# {'timestamp': 1688631176, 'latitude': 51.4244, 'longitude': -90.4862}
# {'timestamp': 1688631186, 'latitude': 51.4797, 'longitude': -89.4923}
# {'timestamp': 1688631197, 'latitude': 51.528, 'longitude': -88.4465}
# {'timestamp': 1688631207, 'latitude': 51.5645, 'longitude': -87.4486}
# {'timestamp': 1688631217, 'latitude': 51.5918, 'longitude': -86.4492}
# ...

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature

#extracting latitude and longitude coordinates
latitudes = [point['latitude'] for point in data_points]
longitudes = [point['longitude'] for point in data_points]

#creating the map
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

#map to cover entire globe
ax.set_global()

#coastlines, countries, and borders
ax.coastlines()
ax.add_feature(cfeature.BORDERS)

#plotting the path of the ISS on the map
ax.plot(longitudes, latitudes, marker='o', markersize=1, color='blue', transform=ccrs.PlateCarree())

#plot title
ax.set_title('Path of the International Space Station: 07/01/23, 9PM')

#showing map and plot
plt.show()
